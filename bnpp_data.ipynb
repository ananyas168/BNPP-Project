# %% [markdown]
# <a href="https://colab.research.google.com/github/ananyas168/BNPP-Project/blob/main/bnpp_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('/content/train.csv', header = None)
df.columns
df= df.drop(columns=[0], axis=1)

# %%
df[1].plot(kind = 'line', figsize = [12,8])
df[2].plot(kind = 'line', figsize = [12,8])
df[3].plot(kind = 'line', figsize = [12,8])
df[4].plot(kind = 'line', figsize = [12,8])

# %%
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt



corrMatrix = df.corr()
sn.heatmap(corrMatrix, annot=True)
plt.show()
